# %% [markdown]
# # Guidelines for data treatment with SCARLET
#
# This notebook, present how to treat data with SCARLET python API

# %% [markdown]
# ## 1. Workflow initialization:

# %%
from scarlet.workflow.context import initialize_workflow_context_from_raw_directory, WorkflowContext

RAW_DIR = "/home/achennev/python/scarlet/data/D11/raw/" # change this to the path where your raw data is located
OUTPUT_DIR = "/home/achennev/python/scarlet/data/D11/processed/" # change this to the path where you want to store the output data
INSTRUMENT_NAME = "D11" # instrument name, used to find the correct configuration files

RAW_DIR, OUTPUT_DIR
# Out:
# ('/home/achennev/python/scarlet/data/D11/raw/',
#  '/home/achennev/python/scarlet/data/D11/processed/')

# %% [markdown]
# Initialize the work flow context using the `initialize_workflow_context_from_raw_directory` function. This function perform several task :
#
#  - Read all the data files present in the raw data driectory, convert them into a nexus file with a generic file architecure and save them into the output_directory.
#
#  - Make a list of instrument configuration used during the experiment (collimation, detector distance, wavelength)
#
#  - Detect if data file corresponds to "empty_cell", "dark", "water" or "empty_beam" measurements based on the sample name.

# %%
w = initialize_workflow_context_from_raw_directory(
    RAW_DIR,
    instrument_name=INSTRUMENT_NAME,
    transmission_strategy="opaque_beamstop",
    output_dir=OUTPUT_DIR,
    overwrite=True,
)
# If orverwrite is set to True, the output directory will be cleared before running the workflow. If set to False, the workflow will not run if the output directory already exists.

# %% [markdown]
# ## 2. Save workflow and filter files
# Sometimes, the raw_data folder contains many files that are not necessary for the data treatement and complexify the workflow operation. The 'WorkflowContext ' shall only contains runs intended to be treated and references (empty_cell,...).
#
# For this prupose, a manual filtering or the edition of a csv file is possible.
#
# First save the current state of the workflow in a csv file using the command:

# %%
w.write_runs_table_csv(OUTPUT_DIR + 'runs_table.csv', overwrite=True)
# Out:
# PosixPath('/home/achennev/python/scarlet/data/D11/processed/runs_table.csv')

# %% [markdown]
# After editing the csv file, you can run the workflow with the following code in order to load the filtered csv files. The runs can be displayed using the `w.runs_table()` command.

# %%
w.update_from_runs_table_csv(OUTPUT_DIR + "runs_table_filtered.csv")
w.runs_table()
# Out:
# sample_name,config_id,mode,entity,thickness,transmission,file_path
# open beam 40m,config_1,scattering,sample,,,010996.nxs
# MT cell 40m,config_1,scattering,empty_cell,,,010997.nxs
# Acb74 80% D2O,config_1,scattering,sample,,,010998.nxs
# Acb74 80% D2O,config_2,scattering,sample,,,010999.nxs
# MT cell 8m,config_2,scattering,empty_cell,,,011000.nxs
# open beam 8m,config_2,scattering,empty_beam,,,011001.nxs
# open beam 8m,config_2,transmission,empty_beam,,,011002.nxs
# MT cell trans,config_2,transmission,empty_cell,,,011003.nxs
# MT cell,config_3,scattering,empty_cell,,,011004.nxs
# Acb74 80% D2O,config_3,scattering,sample,,,011005.nxs
# open beam 1.4m,config_3,transmission,empty_beam,,,011006.nxs
# SM60 silane 76% tolu,config_3,scattering,sample,,,011007.nxs
# Acb74 67.8% D2O,config_3,scattering,sample,,,011008.nxs
# Acb74 73.1% D2O,config_3,scattering,sample,,,011009.nxs
# Acb74 80% D2O,config_3,scattering,sample,,,011010.nxs
# Acb74 76% tolu,config_3,scattering,sample,,,011011.nxs
# Acb74 79.4% tolu,config_3,scattering,sample,,,011012.nxs
# SM60 H2O2 76% tolu,config_3,scattering,sample,,,011013.nxs
# SM60 silane 76% tolu,config_2,scattering,sample,,,011014.nxs
# Acb74 67.8% D2O,config_2,scattering,sample,,,011015.nxs
# Acb74 73.1% D2O,config_2,scattering,sample,,,011016.nxs
# Acb74 80% D2O,config_2,scattering,sample,,,011017.nxs
# Acb74 76% tolu,config_2,scattering,sample,,,011018.nxs
# Acb74 79.4% tolu,config_2,scattering,sample,,,011019.nxs
# SM60 H2O2 76% tolu,config_2,scattering,sample,,,011020.nxs
# SM60 silane 76% tolu,config_4,transmission,sample,,,011021.nxs
# Acb74 67.8% D2O,config_4,transmission,sample,,,011022.nxs
# Acb74 73.1% D2O,config_4,transmission,sample,,,011023.nxs
# Acb74 80% D2O,config_4,transmission,sample,,,011024.nxs
# Acb74 76% tolu,config_4,transmission,sample,,,011025.nxs
# Acb74 79.4% tolu,config_4,transmission,sample,,,011026.nxs
# SM60 H2O2 76% tolu,config_4,transmission,sample,,,011027.nxs
# SM60 silane 76% tolu,config_1,scattering,sample,,,011028.nxs
# Acb74 67.8% D2O,config_1,scattering,sample,,,011029.nxs
# Acb74 73.1% D2O,config_1,scattering,sample,,,011030.nxs
# Acb74 80% D2O,config_1,scattering,sample,,,011031.nxs
# Acb74 76% tolu,config_1,scattering,sample,,,011032.nxs
# Acb74 79.4% tolu,config_1,scattering,sample,,,011033.nxs
# SM60 H2O2 76% tolu,config_1,transmission,sample,,,011034.nxs
# Acb74 73.1% D2O bis,config_1,scattering,sample,,,011035.nxs
# open beam 5.5m coll,config_4,transmission,empty_beam,,,011036.nxs
# MT cell trans 5.5coll,config_4,transmission,empty_cell,,,011037.nxs
# Acb74 73.1% D2O bis,config_1,scattering,sample,,,011038.nxs
# Cd,config_1,scattering,dark,,,011333.nxs
# Acb75 73.1D,config_1,scattering,sample,,,011334.nxs
# Acb75 70.7D,config_1,scattering,sample,,,011335.nxs
# Acb75 75.5D,config_1,scattering,sample,,,011336.nxs
# Acb49 1month D2O 73.1D,config_1,scattering,sample,,,011337.nxs
# Acb49 1month H2O 73.1D,config_1,scattering,sample,,,011338.nxs
# SM60 73.1 D2O,config_1,scattering,sample,,,011339.nxs
# toluD 76,config_1,scattering,sample,,,011340.nxs
# SM60 toluD 76,config_1,scattering,sample,,,011341.nxs
# Acb75 75.5D,config_1,scattering,sample,,,011342.nxs
# Cd,config_2,scattering,dark,,,011343.nxs
# Acb75 73.1D,config_2,scattering,sample,,,011344.nxs
# Acb75 70.7D,config_2,scattering,sample,,,011345.nxs
# Acb75 75.5D,config_2,scattering,sample,,,011346.nxs
# Acb49 1month D2O 73.1D,config_2,scattering,sample,,,011347.nxs
# Acb49 1month H2O 73.1D,config_2,scattering,sample,,,011348.nxs
# SM60 73.1 D2O,config_2,scattering,sample,,,011349.nxs
# toluD 76,config_2,scattering,sample,,,011350.nxs
# SM60 toluD 76,config_2,scattering,sample,,,011351.nxs
# Acb75 73.1D,config_4,transmission,sample,,,011352.nxs
# Acb75 70.7D,config_4,transmission,sample,,,011353.nxs
# Acb75 75.5D,config_4,transmission,sample,,,011354.nxs
# Acb49 1month D2O 73.1D,config_4,transmission,sample,,,011355.nxs
# Acb49 1month H2O 73.1D,config_4,transmission,sample,,,011356.nxs
# SM60 73.1 D2O,config_4,transmission,sample,,,011357.nxs
# toluD 76,config_4,transmission,sample,,,011358.nxs
# SM60 toluD 76,config_4,transmission,sample,,,011359.nxs
# Cd,config_3,scattering,dark,,,011360.nxs
# Acb75 73.1D,config_3,scattering,sample,,,011361.nxs
# Acb75 70.7D,config_3,scattering,sample,,,011362.nxs
# Acb75 75.5D,config_3,scattering,sample,,,011363.nxs
# Acb49 1month D2O 73.1D,config_3,scattering,sample,,,011364.nxs
# Acb49 1month H2O 73.1D,config_3,scattering,sample,,,011365.nxs
# SM60 73.1 D2O,config_3,scattering,sample,,,011366.nxs
# toluD 76,config_3,scattering,sample,,,011367.nxs
# SM60 toluD 76,config_3,scattering,sample,,,011368.nxs
# open beam 1.4m 2att,config_3,transmission,sample,,,011369.nxs
# acb75 75D,config_2,scattering,sample,,,011950.nxs
# Acb75 76D,config_2,scattering,sample,,,011951.nxs
# Acb106E 70.7D,config_2,scattering,sample,,,011952.nxs
# Acb106E73.1D,config_2,scattering,sample,,,011953.nxs
# Acb106E 75.5D,config_2,scattering,sample,,,011954.nxs
# Acb106 70.7D,config_2,scattering,sample,,,011955.nxs
# acb106 73.1D,config_2,scattering,sample,,,011956.nxs
# acb106 75.5D,config_2,scattering,sample,,,011957.nxs
# SM60 PSNH2 10k 76% dTol,config_2,scattering,sample,,,011958.nxs
# acb75 75D,config_4,transmission,sample,,,011959.nxs
# Acb75 76D,config_4,transmission,sample,,,011960.nxs
# Acb106E 70.7D,config_4,transmission,sample,,,011961.nxs
# Acb106E 73.1D,config_4,transmission,sample,,,011962.nxs
# Acb106E 75.5D,config_4,transmission,sample,,,011963.nxs
# Acb106 70.7D,config_4,transmission,sample,,,011964.nxs
# Acb106 73.1D,config_4,transmission,sample,,,011965.nxs
# Acb106 75.5D,config_4,transmission,sample,,,011966.nxs
# SM60 PSNH2 10k 76 dTol,config_4,transmission,sample,,,011967.nxs
# acb75 75D,config_3,scattering,sample,,,011968.nxs
# Acb75 76D,config_3,scattering,sample,,,011969.nxs
# Acb106E 70.7D,config_3,scattering,sample,,,011970.nxs
# Acb106E 73.1D,config_3,scattering,sample,,,011971.nxs
# Acb106E 75.5D,config_3,scattering,sample,,,011972.nxs
# Acb106 70.7D,config_3,scattering,sample,,,011973.nxs
# Acb106 73.1D,config_3,scattering,sample,,,011974.nxs
# Acb106 75.5D,config_3,scattering,sample,,,011975.nxs
# SM60 PSNH2 10k 76 dTol,config_3,scattering,sample,,,011976.nxs

# %% [markdown]
# The entity column serves as a sample description. It can be set to :
# - sample : normal sample
# - water: water file allowing to compute flatfield
# - empty_cell : empty_cell for substraction
# - dark: B4C, Cd file for substraction
# - empty_beam : note that a transmission empty_beam is required to compute the transmissions.
#
# The mode column can also be changed in case of miss recognition.
#
# The config_id column is just a simple identification string per confiruration used. The configurations parameters can be displayed using the `WorkflowContext.configurations_table()` method

# %%
w.configurations_table()
# Out:
# config_id,wavelength,sample_detector_distance,collimation_distance,last_aperture_to_sample_distance,aperture1,aperture2,notes
# config_1,6.00019 A,38.998 m,40.5 m,0 m,slit x=0.03 m y=0.05 m,slit x=0.007 m y=0.01 m,
# config_2,5.99935 A,8.003 m,8 m,0 m,slit x=0.045 m y=0.05 m,slit x=0.007 m y=0.01 m,
# config_3,6.00074 A,1.404 m,5.5 m,0 m,slit x=0.045 m y=0.05 m,slit x=0.007 m y=0.01 m,
# config_4,5.99935 A,7.995 m,5.5 m,0 m,slit x=0.045 m y=0.05 m,slit x=0.007 m y=0.01 m,

# %% [markdown]
# The `WorkflowContext` can be saved a a nexus file for futur use using the following commands:

# %%
w.save("workflow.nxs", overwrite=True)
# load the workflow context from the saved file
w = WorkflowContext.load("workflow.nxs")

# %% [markdown]
# ## 3. Transmission computation
#
# The computation of the detector is performed using the detector named `detector0` in the nexus files refering to the central detector. During the initialization of the `WorkflowContext`, the ROI for transmission measurements is automatically detected.
#
# The ROIs per config can be retrieved and modified using the following methods:

# %%
# read roi
print(w.get_roi('config_1'))
# set roi
# w.set_roi('config_10', [61, 65, 62, 64])  # Example ROI coordinates
# w.set_roi('config_9', [60, 64, 61, 63])  # Example ROI coordinates
# Out:
# None

# %% [markdown]
# The computation of the transmission is perfomd using the `WorkflowContext.compute_transmissions()` method:

# %%
w.compute_transmissions()
# save transmission in csv file once computed
w.write_runs_table_csv("OUTPUT_DIR + 'runs_table_with_tr.csv'",overwrite=True)
w.runs_table()
# Out:
# sample_name,config_id,mode,entity,thickness,transmission,file_path
# open beam 40m,config_1,scattering,sample,,,010996.nxs
# MT cell 40m,config_1,scattering,empty_cell,,,010997.nxs
# Acb74 80% D2O,config_1,scattering,sample,,,010998.nxs
# Acb74 80% D2O,config_2,scattering,sample,,,010999.nxs
# MT cell 8m,config_2,scattering,empty_cell,,,011000.nxs
# open beam 8m,config_2,scattering,empty_beam,,,011001.nxs
# open beam 8m,config_2,transmission,empty_beam,,,011002.nxs
# MT cell trans,config_2,transmission,empty_cell,,0.944925,011003.nxs
# MT cell,config_3,scattering,empty_cell,,,011004.nxs
# Acb74 80% D2O,config_3,scattering,sample,,,011005.nxs
# open beam 1.4m,config_3,transmission,empty_beam,,,011006.nxs
# SM60 silane 76% tolu,config_3,scattering,sample,,,011007.nxs
# Acb74 67.8% D2O,config_3,scattering,sample,,,011008.nxs
# Acb74 73.1% D2O,config_3,scattering,sample,,,011009.nxs
# Acb74 80% D2O,config_3,scattering,sample,,,011010.nxs
# Acb74 76% tolu,config_3,scattering,sample,,,011011.nxs
# Acb74 79.4% tolu,config_3,scattering,sample,,,011012.nxs
# SM60 H2O2 76% tolu,config_3,scattering,sample,,,011013.nxs
# SM60 silane 76% tolu,config_2,scattering,sample,,,011014.nxs
# Acb74 67.8% D2O,config_2,scattering,sample,,,011015.nxs
# Acb74 73.1% D2O,config_2,scattering,sample,,,011016.nxs
# Acb74 80% D2O,config_2,scattering,sample,,,011017.nxs
# Acb74 76% tolu,config_2,scattering,sample,,,011018.nxs
# Acb74 79.4% tolu,config_2,scattering,sample,,,011019.nxs
# SM60 H2O2 76% tolu,config_2,scattering,sample,,,011020.nxs
# SM60 silane 76% tolu,config_4,transmission,sample,,0.881929,011021.nxs
# Acb74 67.8% D2O,config_4,transmission,sample,,0.860649,011022.nxs
# Acb74 73.1% D2O,config_4,transmission,sample,,0.869075,011023.nxs
# Acb74 80% D2O,config_4,transmission,sample,,0.890012,011024.nxs
# Acb74 76% tolu,config_4,transmission,sample,,0.889855,011025.nxs
# Acb74 79.4% tolu,config_4,transmission,sample,,0.904712,011026.nxs
# SM60 H2O2 76% tolu,config_4,transmission,sample,,0.884974,011027.nxs
# SM60 silane 76% tolu,config_1,scattering,sample,,,011028.nxs
# Acb74 67.8% D2O,config_1,scattering,sample,,,011029.nxs
# Acb74 73.1% D2O,config_1,scattering,sample,,,011030.nxs
# Acb74 80% D2O,config_1,scattering,sample,,,011031.nxs
# Acb74 76% tolu,config_1,scattering,sample,,,011032.nxs
# Acb74 79.4% tolu,config_1,scattering,sample,,,011033.nxs
# SM60 H2O2 76% tolu,config_1,transmission,sample,,,011034.nxs
# Acb74 73.1% D2O bis,config_1,scattering,sample,,,011035.nxs
# open beam 5.5m coll,config_4,transmission,empty_beam,,,011036.nxs
# MT cell trans 5.5coll,config_4,transmission,empty_cell,,0.947001,011037.nxs
# Acb74 73.1% D2O bis,config_1,scattering,sample,,,011038.nxs
# Cd,config_1,scattering,dark,,,011333.nxs
# Acb75 73.1D,config_1,scattering,sample,,,011334.nxs
# Acb75 70.7D,config_1,scattering,sample,,,011335.nxs
# Acb75 75.5D,config_1,scattering,sample,,,011336.nxs
# Acb49 1month D2O 73.1D,config_1,scattering,sample,,,011337.nxs
# Acb49 1month H2O 73.1D,config_1,scattering,sample,,,011338.nxs
# SM60 73.1 D2O,config_1,scattering,sample,,,011339.nxs
# toluD 76,config_1,scattering,sample,,,011340.nxs
# SM60 toluD 76,config_1,scattering,sample,,,011341.nxs
# Acb75 75.5D,config_1,scattering,sample,,,011342.nxs
# Cd,config_2,scattering,dark,,,011343.nxs
# Acb75 73.1D,config_2,scattering,sample,,,011344.nxs
# Acb75 70.7D,config_2,scattering,sample,,,011345.nxs
# Acb75 75.5D,config_2,scattering,sample,,,011346.nxs
# Acb49 1month D2O 73.1D,config_2,scattering,sample,,,011347.nxs
# Acb49 1month H2O 73.1D,config_2,scattering,sample,,,011348.nxs
# SM60 73.1 D2O,config_2,scattering,sample,,,011349.nxs
# toluD 76,config_2,scattering,sample,,,011350.nxs
# SM60 toluD 76,config_2,scattering,sample,,,011351.nxs
# Acb75 73.1D,config_4,transmission,sample,,0.904601,011352.nxs
# Acb75 70.7D,config_4,transmission,sample,,0.900208,011353.nxs
# Acb75 75.5D,config_4,transmission,sample,,0.907612,011354.nxs
# Acb49 1month D2O 73.1D,config_4,transmission,sample,,0.851401,011355.nxs
# Acb49 1month H2O 73.1D,config_4,transmission,sample,,0.832529,011356.nxs
# SM60 73.1 D2O,config_4,transmission,sample,,0.851975,011357.nxs
# toluD 76,config_4,transmission,sample,,0.6583,011358.nxs
# SM60 toluD 76,config_4,transmission,sample,,0.876069,011359.nxs
# Cd,config_3,scattering,dark,,,011360.nxs
# Acb75 73.1D,config_3,scattering,sample,,,011361.nxs
# Acb75 70.7D,config_3,scattering,sample,,,011362.nxs
# Acb75 75.5D,config_3,scattering,sample,,,011363.nxs
# Acb49 1month D2O 73.1D,config_3,scattering,sample,,,011364.nxs
# Acb49 1month H2O 73.1D,config_3,scattering,sample,,,011365.nxs
# SM60 73.1 D2O,config_3,scattering,sample,,,011366.nxs
# toluD 76,config_3,scattering,sample,,,011367.nxs
# SM60 toluD 76,config_3,scattering,sample,,,011368.nxs
# open beam 1.4m 2att,config_3,transmission,sample,,3.24608,011369.nxs
# acb75 75D,config_2,scattering,sample,,,011950.nxs
# Acb75 76D,config_2,scattering,sample,,,011951.nxs
# Acb106E 70.7D,config_2,scattering,sample,,,011952.nxs
# Acb106E73.1D,config_2,scattering,sample,,,011953.nxs
# Acb106E 75.5D,config_2,scattering,sample,,,011954.nxs
# Acb106 70.7D,config_2,scattering,sample,,,011955.nxs
# acb106 73.1D,config_2,scattering,sample,,,011956.nxs
# acb106 75.5D,config_2,scattering,sample,,,011957.nxs
# SM60 PSNH2 10k 76% dTol,config_2,scattering,sample,,,011958.nxs
# acb75 75D,config_4,transmission,sample,,0.859799,011959.nxs
# Acb75 76D,config_4,transmission,sample,,0.890072,011960.nxs
# Acb106E 70.7D,config_4,transmission,sample,,0.855401,011961.nxs
# Acb106E 73.1D,config_4,transmission,sample,,0.894517,011962.nxs
# Acb106E 75.5D,config_4,transmission,sample,,0.892048,011963.nxs
# Acb106 70.7D,config_4,transmission,sample,,0.854748,011964.nxs
# Acb106 73.1D,config_4,transmission,sample,,0.875948,011965.nxs
# Acb106 75.5D,config_4,transmission,sample,,0.901151,011966.nxs
# SM60 PSNH2 10k 76 dTol,config_4,transmission,sample,,0.848739,011967.nxs
# acb75 75D,config_3,scattering,sample,,,011968.nxs
# Acb75 76D,config_3,scattering,sample,,,011969.nxs
# Acb106E 70.7D,config_3,scattering,sample,,,011970.nxs
# Acb106E 73.1D,config_3,scattering,sample,,,011971.nxs
# Acb106E 75.5D,config_3,scattering,sample,,,011972.nxs
# Acb106 70.7D,config_3,scattering,sample,,,011973.nxs
# Acb106 73.1D,config_3,scattering,sample,,,011974.nxs
# Acb106 75.5D,config_3,scattering,sample,,,011975.nxs
# SM60 PSNH2 10k 76 dTol,config_3,scattering,sample,,,011976.nxs

# %% [markdown]
# ## 4. Masking

# %% [markdown]
# The edition of masks can be done using the `scarlet viewer` GUI. To run this graphical interface just run `scarlet viewer` command in a terminal with the appropriate virtual environnment activated. The mask files shall be saved in the output directory in order to be found by the workflow.
#
# Each mask file stores the configuration over which they have been drawn. The `WorkflowContext` can automatically adress them to a specc

# %%
w.attach_mask_bundles_from_output_dir()
# display the mask files for a specific configuration
w.mask_files
# Out:
# {'config_1': PosixPath('/home/achennev/python/scarlet/data/SAM/processed/mask_config1.nxs'),
#  'config_3': PosixPath('/home/achennev/python/scarlet/data/SAM/processed/mask_config3.nxs'),
#  'config_4': PosixPath('/home/achennev/python/scarlet/data/SAM/processed/mask_config4.nxs'),
#  'config_2': PosixPath('/home/achennev/python/scarlet/data/SAM/processed/masks_config2.nxs')}

# %% [markdown]
# Manual attibution of a mask file can be done using the following command:

# %%
# w.set_mask_file(config_id='config_10', file_path='/path/to/mask_file')

# %% [markdown]
# ## 5. Flatfield / water normalization

# %% [markdown]
# The `water` entity in the run table can be used to generate flatfields files for normalization by water.
# To build a flatfield file for a specific configuration use the following command:

# %%
w.build_water_flatfield(config_id="config_1")
w.build_water_flatfield(config_id="config_2")
w.build_water_flatfield(config_id="config_3")
# Out:
# PosixPath('/home/achennev/python/scarlet/data/SAM/processed/flatfield_config_3.nxs')

# %% [markdown]
# The flatflied file is saved in the output directory. It can also be set manually with:

# %%
# set flatfield file for a specific configuration
# w.set_flatfield(config_id="config_10", file_path="flat_field_path")
# get the flatfield file for a specific configuration
w.get_flatfield(config_id="config_9")

# %% [markdown]
# If no water file is available at a given configuration we can declare to use the flatfield of one config to another one using the following command.

# %%
w.set_flatfield_source(config_id="config_4", source_config_id="config_2")
# w.get_flatfield(config_id="config_9")
# Out:
# 'config_2'

# %% [markdown]
# ## 6. Reduction pipeline
#
# Once the workflow is set, the data reduction can be performed using a `Pipeline`. The default option perform the following reduction steps:
# - Subtract dark and empty_cell
# - Division by water flatfield
# - Azimutal averaging
# - save processed data in the nexus files in the `processed` entry
# - save the processed data as a .txt file for each configuration and each detector.

# %% [markdown]
# The reducrion can be perform for a given sample at a given configuration using:

# %%
from scarlet.workflow.pipeline import ReductionPipeline, ReductionState
pipeline = ReductionPipeline().default()
state = pipeline.run_for_sample(workflow=w, sample_name="acb106 75.5D", config_id="config_1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 from scarlet.workflow.pipeline import ReductionPipeline, ReductionState
#       2 pipeline = ReductionPipeline().default()
# ----> 3 state = pipeline.run_for_sample(workflow=w, sample_name="acb106 75.5D", config_id="config_1")
#
# File ~/python/scarlet/src/scarlet/workflow/pipeline.py:804, in ReductionPipeline.run_for_sample(self, workflow, sample_name, config_id)
#     802 def run_for_sample(self, workflow: WorkflowContext, sample_name: str, config_id: str) -> ReductionState:
#     803     state = ReductionState(sample_name=sample_name, config_id=config_id, workflow=workflow)
# --> 804     return self.run(state)
#
# File ~/python/scarlet/src/scarlet/workflow/pipeline.py:798, in ReductionPipeline.run(self, state)
#     796 def run(self, state: ReductionState) -> ReductionState:
#     797     for step in self.steps:
# --> 798         state = step.fn(state)
#     799         state.reductions_steps.append(step.name)
#     800     return state
#
# File ~/python/scarlet/src/scarlet/workflow/pipeline.py:596, in normalization_step(state)
#     594 flatfield_path = state.workflow.get_flatfield(state.config_id)
#     595 if flatfield_path is None:
# --> 596     flatfield_path = state.workflow.build_water_flatfield(state.config_id)
#     597     if effective_config_id == state.config_id:
#     598         state.notes.append(f"Prepared water flatfield for {state.config_id}")
#
# File ~/python/scarlet/src/scarlet/workflow/context.py:1372, in WorkflowContext.build_water_flatfield(self, config_id, output_path, overwrite, detector_number_for_transmission)
#    1369 """Compute and persist the water flatfield for one configuration."""
#    1370 from .normalization import build_water_flatfield_from_workflow_context
# -> 1372 return build_water_flatfield_from_workflow_context(
#    1373     self,
#    1374     config_id,
#    1375     output_path=output_path,
#    1376     overwrite=overwrite,
#    1377     detector_number_for_transmission=detector_number_for_transmission,
#    1378 )
#
# File ~/python/scarlet/src/scarlet/workflow/normalization.py:398, in build_water_flatfield_from_workflow_context(workflow, config_id, output_path, overwrite, detector_number_for_transmission)
#     395     workflow.set_flatfield(source_config_id, output_path)
#     396     return output_path
# --> 398 water_scattering_key, water_scattering_path = _require_reference_run(
#     399     workflow,
#     400     config_id=source_config_id,
#     401     entity="water",
#     402     mode="scattering",
#     403 )
#     405 water_scattering = nexus_reader.read_all_detectors(
#     406     water_scattering_path,
#     407     normalize_by_monitor=True,
#     408     correct_deadtime=True,
#     409 )
#     410 dark_path = workflow.get_dark(source_config_id)
#
# File ~/python/scarlet/src/scarlet/workflow/normalization.py:59, in _require_reference_run(workflow, config_id, entity, mode)
#      57 selected = _select_reference_run(workflow, config_id=config_id, entity=entity, mode=mode)
#      58 if selected is None:
# ---> 59     raise ValueError(f"Missing {entity} {mode} reference for configuration {config_id!r}")
#      60 return selected
#
# ValueError: Missing water scattering reference for configuration 'config_1'

# %% [markdown]
# Or for the all workflow using:

# %%
pipeline.run_all(w)

# %% [markdown]
# The pipleline reduction steps can be enriched with other reduction scheme. If you have any suggestion, please contact me.

# %% [markdown]
# ## 6. Concatenation of configurations

# %%
from scarlet.workflow.pipeline import StichingPipeline
stitch = StichingPipeline(w)
stitch.run_all(scale_on="config_1")

# %%
w.beam_centers
# Out:
# {'config_1': {0: (64.05600379521202, 127.37534577241983)},
#  'config_2': {0: (64.14683457824741, 127.54541264346877)},
#  'config_3': {0: (64.51615344177192, 126.74968447711399)},
#  'config_4': {0: (62.95655366861189, 126.5736607435578)}}
